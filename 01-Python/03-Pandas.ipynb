# %% [raw]
# ---
# code-fold: false
# ---

# %% [markdown]
# ## Pandas
#
# Open in Colab [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/febse/opt2025-de/blob/main/01-Python/03-Pandas.ipynb)
#
# Während NumPy für die Arbeit mit Vektoren und Matritzen gedacht ist, ist Pandas für die Arbeit mit Tabellen gedacht. Pandas ist eine Python-Bibliothek, die auf NumPy aufbaut und die Arbeit mit Tabellen in Python erleichtert. Pandas ist eine Abkürzung für "Python Data Analysis Library" und wird in der Regel mit `pd` abgekürzt.

# %%
import pandas as pd

# %% [markdown]
# ## Series
#
# Die einfachste Datenstruktur in Pandas ist die `Series`. Eine `Series` ist eine eindimensionale Datenstruktur, die mit einem NumPy-Array vergleichbar ist (eigentlich ist es ein NumPy Array, verknüpft mit einem Index). Eine `Series` kann mit der Funktion `pd.Series()` erstellt werden. Als Argument wird ein Array übergeben. Die `Series` hat einen Index, der standardmäßig mit 0 beginnt. Der Index kann mit dem Argument `index` angepasst werden. Der Index kann ein Array von Strings sein, um die Elemente der `Series` zu benennen.

# %%
# Erstellen einer Series
s = pd.Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Erstellen einer Series mit Index
s1 = pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'])
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# Die `Series` hat eine Reihe von Methoden, die aufgerufen werden können. Eine Übersicht über die Methoden kann mit `help(pd.Series)` aufgerufen werden. Die wichtigsten Methoden sind:

# %%
# Zugriff auf den Index
s1.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='str')

# %%
# Zugriff auf die Werte
s1.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
# Zugriff auf ein Element
s1['a']
# Out:
# np.int64(1)

# %%
# Zugriff auf mehrere Elemente
s1[['a', 'c', 'e']]
# Out:
# a    1
# c    3
# e    5
# dtype: int64

# %%
# Zugriff auf ein Element mit dem Ganzzahl-Index
s1.iloc[0]
# Out:
# np.int64(1)

# %%
# Zugriff auf mehrere Elemente mit dem Index
s1.loc["a"]
# Out:
# np.int64(1)

# %%
s1.loc[["a", "c", "e"]]
# Out:
# a    1
# c    3
# e    5
# dtype: int64

# %%
s1.sum()
# Out:
# np.int64(15)

# %%
s1.mean()
# Out:
# np.float64(3.0)

# %%
s1.std()
# Out:
# np.float64(1.5811388300841898)

# %%
s1.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# dtype: float64

# %%
s1 > 3
# Out:
# a    False
# b    False
# c    False
# d     True
# e     True
# dtype: bool

# %%
s1[s1 > 3]
# Out:
# d    4
# e    5
# dtype: int64

# %% [markdown]
# ## Aufgabe 1
#
# Erstellen Sie eine Series names `age` mit den Werten `[23, 45, 56, 34, 23]` und den Indizes `['Alice', 'Bob', 'Charlie', 'David', 'Eve']`. Geben Sie die Series aus.
#
# - Berechnen Sie das mittlere Alter der Personen in der Series.
# - Berechnen Sie das mittlere Alter von ['Alice', 'Charlie', 'Eve'].
# - Berechnen Sie die das mittlere Alter von den Personen, die jünger als 30 sind.
# - Ersetzen Die den Alterswert von 'Bob' durch 50.

# %%
age = pd.Series([23, 45, 56, 34, 23], index = ['Alice', 'Bob', 'Charlie', 'David', 'Eve'])

print(age)

print("Mittleres Alter von allen:", age.mean())

print("Das mittlere Alter von Alice, Charlie und Eve:", age.loc[['Alice', 'Charlie', 'Eve']].mean())

age["Bob"] = 50

print(age)
# Out:
# Alice      23
# Bob        45
# Charlie    56
# David      34
# Eve        23
# dtype: int64
# Mittleres Alter von allen: 36.2
# Das mittlere Alter von Alice, Charlie und Eve: 34.0
# Alice      23
# Bob        50
# Charlie    56
# David      34
# Eve        23
# dtype: int64

# %% [markdown]
# ## DataFrame
#
# Das wichtigste Datenobjekt in Pandas ist der `DataFrame`. Ein `DataFrame` ist eine zweidimensionale Datenstruktur, die mit einer Tabelle vergleichbar ist. Ein `DataFrame` kann mit der Funktion `pd.DataFrame()` erstellt werden. Als Argument wird ein Array übergeben. Der `DataFrame` hat einen Index, der standardmäßig mit 0 beginnt. Der Index kann mit dem Argument `index` angepasst werden. Der Index kann ein Array von Strings sein, um die Zeilen des `DataFrame` zu benennen. Die Spalten des `DataFrame` können mit dem Argument `columns` benannt werden.

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 7, 9], [10, 11, 12]], columns=['A', 'B', 'C'])
df
# Out:
#     A   B   C
# 0   1   2   3
# 1   4   5   6
# 2   7   7   9
# 3  10  11  12

# %%
df1 = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 7, 9], [10, 11, 12]],
                   index=['a', 'b', 'c', 'd'],
                   columns=['X', 'Y', 'Z']
                   )
df1
# Out:
#     X   Y   Z
# a   1   2   3
# b   4   5   6
# c   7   7   9
# d  10  11  12

# %% [markdown]
# Alternativ kann ein `DataFrame` auch aus einem Dictionary erstellt werden. Die Schlüssel des Dictionaries werden zu den Spalten des `DataFrame`. Die Werte des Dictionaries können Listen, NumPy-Arrays oder Pandas-`Series` sein.

# %%
df2 = pd.DataFrame({
    'x': [1, 4, 7, 10], 
    'y': [2, 5, 8, 11],
      'z': [3, 6, 9, 12]}
)

# %% [markdown]
# Die `DataFrame` hat eine Reihe von Methoden, die aufgerufen werden können. Eine Übersicht über die Methoden kann mit `help(pd.DataFrame)` aufgerufen werden. Die wichtigsten Methoden sind:

# %%
df1["X"].sum()
# Out:
# np.int64(22)

# %%
df1["X"].mean()
# Out:
# np.float64(5.5)

# %%
df1["X"].std()
# Out:
# np.float64(3.872983346207417)

# %%
df1["X"].describe()
# Out:
# count     4.000000
# mean      5.500000
# std       3.872983
# min       1.000000
# 25%       3.250000
# 50%       5.500000
# 75%       7.750000
# max      10.000000
# Name: X, dtype: float64

# %% [markdown]
# ## Aufgabe 2
#
# Estellen Sie einen `DataFrame` mit den Spalten `age` und `weight` und den Werten `[[23, 45, 56, 34, 23], [70, 80, 90, 100, 110]]` und den Indizes `['Alice', 'Bob', 'Charlie', 'David', 'Eve']`. Geben Sie den `DataFrame` aus.
#
# - Finden Sie das größte Gewicht im `DataFrame`.
# - Finden Sie das Gewicht von 'Charlie'.

# %% [markdown]
# ## Axes
#
# Die `axes` eines `DataFrame` sind die Zeilen und Spalten des `DataFrame`. Die Zeilen können mit `df.index` und die Spalten mit `df.columns` abgerufen werden.
# Die Eigenschaft (property) `shape` gibt die Anzahl der Zeilen und Spalten des `DataFrame` zurück.

# %%
df1.shape
# Out:
# (4, 3)

# %% [markdown]
# Viele Methoden können auf die Zeilen und Spalten des `DataFrame` angewendet werden.

# %%
df1
# Out:
#     X   Y   Z
# a   1   2   3
# b   4   5   6
# c   7   7   9
# d  10  11  12

# %%
df1.mean(axis=0)
# Out:
# X    5.50
# Y    6.25
# Z    7.50
# dtype: float64

# %%
df1.mean(axis=1)
# Out:
# a     2.000000
# b     5.000000
# c     7.666667
# d    11.000000
# dtype: float64

# %%
df1.mean()
# Out:
# X    5.50
# Y    6.25
# Z    7.50
# dtype: float64

# %% [markdown]
# ## Neue Spalten hinzufügen
#
# Eine neue Spalte kann zu einem `DataFrame` hinzugefügt werden, indem ein neues Array als Wert der neuen Spalte zugewiesen wird. Die neue Spalte wird automatisch an das Ende des `DataFrame` hinzugefügt.

# %%
df1["New"] = [1, 2, 3, 4]
df1.head()
# Out:
#     X   Y   Z  New
# a   1   2   3    1
# b   4   5   6    2
# c   7   7   9    3
# d  10  11  12    4

# %% [markdown]
# Häufig wird eine neue Spalte aus bestehenden Spalten berechnet. Dazu können die bestehenden Spalten wie normale Arrays verwendet werden. Die neue Spalte wird automatisch an das Ende des `DataFrame` hinzugefügt.

# %%
df1["X_minus_Y"] = df1["X"] - df1["Y"]
df1.head()
# Out:
#     X   Y   Z  New  X_minus_Y
# a   1   2   3    1         -1
# b   4   5   6    2         -1
# c   7   7   9    3          0
# d  10  11  12    4         -1

# %%
df1["X_2"] = 2 *df1["X"]
df1.head()
# Out:
#     X   Y   Z  New  X_minus_Y  X_2
# a   1   2   3    1         -1    2
# b   4   5   6    2         -1    8
# c   7   7   9    3          0   14
# d  10  11  12    4         -1   20

# %% [markdown]
# ## Aufgabe 3
#
# Benutzen Sie den `DataFrame` `df1` und fügen Sie eine neue Spalte `XY` hinzu, die das Produkt der Spalten `X` und `Y` ist. Finden Sie das Minimum der neuen Spalte `XY`.

# %% [markdown]
# ## Selektieren von Zeilen
#
# Häufig möchten wir nur eine Teilmenge der Zeilen eines `DataFrame` selektieren, z.B. die ersten 5 Zeilen oder die Zeilen, die eine bestimmte Bedingung erfüllen (z.B. Männer/Frauen, beschäftigt/arbeitslos, etc.).

# %%
# Als Beispiel wählen wir die ersten drei Zeilen

df1.iloc[0:2]
# Out:
#    X  Y  Z  New  X_minus_Y  X_2
# a  1  2  3    1         -1    2
# b  4  5  6    2         -1    8

# %%
# Als anderes Beispiel wählen wir die Zeilen, für die X größer als 3 ist

df1[df1["X"] > 3]
# Out:
#     X   Y   Z  New  X_minus_Y  X_2
# b   4   5   6    2         -1    8
# c   7   7   9    3          0   14
# d  10  11  12    4         -1   20

# %%
df1.query("X > 4")
# Out:
#     X   Y   Z  New  X_minus_Y  X_2
# c   7   7   9    3          0   14
# d  10  11  12    4         -1   20

# %% [markdown]
# ## Selektieren von Spalten
#
# Häufig möchten wir nur eine Teilmenge der Spalten eines `DataFrame` selektieren, z.B. die Spalten, die für eine bestimmte Analyse relevant sind.

# %%
df1[["X", "Y"]]
# Out:
#     X   Y
# a   1   2
# b   4   5
# c   7   7
# d  10  11

# %% [markdown]
# ## GroupBy
#
# Mit der Funktion `groupby()` können die Daten in einem `DataFrame` gruppiert werden. Die Funktion `groupby()` gibt ein `DataFrameGroupBy`-Objekt zurück. Mit diesem Objekt können verschiedene Aggregationsfunktionen aufgerufen werden. Die wichtigsten Aggregationsfunktionen sind:
# - `count()`: Anzahl der Elemente
# - `sum()`: Summe der Elemente
# - `mean()`: Mittelwert der Elemente
# - `median()`: Median der Elemente
# - `min()`: Minimum der Elemente
# - `max()`: Maximum der Elemente
# - `std()`: Standardabweichung der Elemente
# - `var()`: Varianz der Elemente
# - `describe()`: Statistische Kennzahlen der Elemente
# - `first()`: Erstes Element
# - `last()`: Letztes Element
# - `nth()`: n-tes Element

# %%
df2 = pd.DataFrame({
    "Name": ["Alice", "Bob", "Mallory", "Mallory", "Bob", "Mallory"],
    "Gender": ["f", "m", "f", "f", "m", "f"],
    "YearOfBirth": [1999, 1985, 1997, 1990, 1987, 1990],
}
)
df2["Age"] = 2024 - df2["YearOfBirth"]
df2.head()
# Out:
#       Name Gender  YearOfBirth  Age
# 0    Alice      f         1999   25
# 1      Bob      m         1985   39
# 2  Mallory      f         1997   27
# 3  Mallory      f         1990   34
# 4      Bob      m         1987   37

# %%
df2_by_gender = df2.groupby("Gender")
df2_by_gender

# %%
df2_by_gender["Age"].mean()
# Out:
# Gender
# f    30.0
# m    38.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Groupby und Transform
#
# Sehr häufig mächten wir eine Spalte aggregieren und das Ergebnis in einer neuen Spalte speichern. Dazu können wir die Methode `transform()` verwenden.

# %%
df2["average_age_by_gender"] = df2.groupby("Gender")["Age"].transform("mean")
df2.head()
# Out:
#       Name Gender  YearOfBirth  Age  average_age_by_gender
# 0    Alice      f         1999   25                   30.0
# 1      Bob      m         1985   39                   38.0
# 2  Mallory      f         1997   27                   30.0
# 3  Mallory      f         1990   34                   30.0
# 4      Bob      m         1987   37                   38.0

# %% [markdown]
# ## Aufgabe 4
#
# Für den Zweck der Buchhaltung in einem Unternehmen soll ein DataFrame erstellt werden, welches die folgenden Spalten enthält:
#
# - Position: Die Position im Unternehmen
# - Arbeitszeit: Die Arbeitszeit pro Woche
# - Lohn: Der wöchentliche Lohn in Euro
#
# Die Werte für die Position sollen aus der folgenden Liste entnommen werden:
#
# ```python
# Position: ['CEO', 'CFO', 'CTO', 'CIO', 'COO', 'CDO', 'CMO', 'CRO', 'CSO', 'CPO']
# Arbeitszeit: [40, 40, 20, 40, 20, 40, 10, 40, 40, 60]
# Gehalt: [10000, 8500, 2000, 3022, 1039, 2500, 3000, 1800, 20000, 10000]
# ```
#
# Erstellen Sie ein DataFrame `accounting` mit den Spalten `Position`, `Arbeitszeit` und `Gehalt`. Geben Sie das DataFrame aus.
#
# - Berechnen Sie die durchschnittliche Arbeitszeit pro Woche.
# - Berechnen Sie die durchschnittliche Arbeitszeit pro Woche je nach Position.
# - Berechnen Sie den durchschnittlichen Lohn je nach Arbeitszeit (größer oder kleiner als 30 Stunden pro Woche).
# - Berechnen Sie die Abweichung des Lohns vom Durchschnittslohn für jede Person in Prozent.
