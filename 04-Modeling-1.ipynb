# %% [markdown]
# # Modelliering (1)

# %% [markdown]
# ## Legierungen
#
# Ein Metallurgieunternehmen möchte eine Legierung aus 30 Prozent Blei (lead), 30 Prozent Zink (zinc) und 40 Prozent Zinn (tin) herstellen. Das Unternehmen kann unterschiedliche Mengen anderer Legierungen (A, B, ..., I) einkaufen, einschmelzen und daraus das gewünschte Produkt herstellen. Die Preise der Legierungen sowie deren Gehalt an Blei, Zink und Zinn (in Prozent) sind in @tbl-alloys angegeben. Welche Mengen von welchen Legierungen sollte das Unternehmen kaufen, um die gewünschte Legierung mit minimalen Kosten herzustellen?
#
# 1. Finden Sie die optimale Lösung in [Excel](https://github.com/febse/opt2026/raw/refs/heads/main/excel/Alloys.xlsx).
# 2. Vereinfachen Sie die Aufgabe, indem Sie die Anforderungen an den Blei- und Zinkanteil ignorieren (lassen Sie nur die Anforderung an den Zinnanteil bestehen), und verwenden Sie nur die Legierungen B, C, H und E. Erstellen Sie eine Grafik, um die optimale Lösung zu finden [(Desmos)](https://www.desmos.com/calculator/9jqnpdf5lo).
#
#
# <!-- Lösung:
#
# - [Excel]({{< var  githubRawPrefix >}}excel/Alloys-Solution.xlsx)
# - [Desmos](https://www.desmos.com/calculator/kcjnxi02da) -->

# %%
#| label: tbl-alloys
#| tbl-cap: "Gehalt an Blei, Zink und Zinn (in Prozent) sowie Preise der verfuegbaren Legierungen"

import pandas as pd

alloys = pd.read_excel("excel/Alloys.xlsx")
alloys
# Out:
#          Alloy     A     B     C   D     E     F     G     H     I
# 0       % Lead  10.0  10.0  40.0  60  30.0  30.0  30.0  50.0  20.0
# 1       % Zinc  10.0  30.0  50.0  30  30.0  40.0  20.0  40.0  30.0
# 2        % Tin  80.0  60.0  10.0  10  40.0  30.0  50.0  10.0  50.0
# 3  Cost USD/kg   4.1   4.3   5.8   6   7.6   7.5   7.3   6.9   7.3

# %% [markdown]
# ## Stadtplanung
#
# Nehmen wir an, dass Sofia mit einem Haushaltsdefizit konfrontiert ist und der Stadtrat ueberlegt, wie die Einnahmen aus der Grundsteuer durch die Umgestaltung staedtischer Immobilien erhoeht werden koennen. Das Projekt besteht aus zwei Teilen -- dem Abriss vernachlässigter und beschädigter Gebaeude und dem Bau neuer Wohnungen.
#
# 1. Zum Planungszeitpunkt besitzt die Gemeinde 300 vernachlaessigte Gebaeude, die abgerissen werden koennen. Jedes von ihnen macht 1000 Quadratmeter frei, und der Abriss kostet 3 000 EUR pro Gebaeude. 15 Prozent der freigewordenen Flaeche sind fuer Strassen, Gehwege und Freiflaechen vorgesehen.
# 2. Auf den freigeraeumten Parzellen kann die Gemeinde vier Arten neuer Wohngebaeude bauen: Einfamilienhaeuser (300 Quadratmeter), Zweifamilienhaeuser (500 Quadratmeter), Dreifamilienhaeuser (700 Quadratmeter) und Vierfamilienhaeuser (900 Quadratmeter). Die erwarteten Steuereinnahmen betragen 1 000 EUR, 1 700 EUR, 2 400 EUR bzw. 2 800 EUR pro Jahr.
# 3. Mindestens 20 Prozent der Neubauten muessen Einfamilienhaeuser sein, Zweifamilienhaeuser muessen mindestens 20 Prozent ausmachen, und Drei- und Vierfamilienhaeuser zusammen muessen mindestens ein Viertel aller Neubauten darstellen.
# 4. Die Baukosten fuer die neuen Haeuser betragen 50 000 EUR, 70 000 EUR, 130 000 EUR bzw. 160 000 EUR.
# 5. Die Gemeinde plant, das Projekt durch einen Bankkredit zu finanzieren, der 15 Millionen EUR nicht ueberschreiten darf.
#
# Wie viele Haeuser jedes Typs sollte die Gemeinde planen zu bauen, um möglichst hohe Steuereinnahmen zu erzielen?
